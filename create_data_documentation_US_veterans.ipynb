# %%
import sys

import datetime
import pickle
import json
import numpy as np
import pandas as pd
import operator
import random
from  scipy import stats



from scipy.stats import norm
from sklearn.neighbors import KernelDensity



import plotly.plotly as py
import plotly.graph_objs as go
from plotly import tools
import plotly.figure_factory as ff


########## to be able to plot offline (without sending the plots to the plotly server every time)
import plotly

import plotly.offline as offline
from plotly.graph_objs import *
from plotly.offline import download_plotlyjs, init_notebook_mode, plot, iplot

init_notebook_mode(connected=True)
################



from IPython.core.display import display,HTML
display(HTML("<style>.container { width:100% !important; }</style>"))  # to make the notebook use the entire width of the browser
# Out:
# <script>requirejs.config({paths: { 'plotly': ['https://cdn.plot.ly/plotly-latest.min']},});if(!window.Plotly) {{require(['plotly'],function(plotly) {window.Plotly=plotly;});}}</script>
# <style>.container { width:100% !important; }</style>

# %%
df_veterans =pd.read_csv('../Data/Mine/Veterans/Reports/Documentation_individual_files_veterans_data.csv',sep=';')
df_veterans
# Out:
#    File_name File_extension  \
# 0     FY1960            csv
# 1     FY1961            csv
# 2     FY1962            csv
# 3     FY1963            csv
# 4     FY1964            csv
# 5     FY1965            csv
# 6     FY1966            csv
# 7     FY1967            csv
# 8     FY1968            csv
# 9     FY1969            csv
# 10    FY1970            csv
# 11    FY1971            csv
# 12    FY1972            csv
# 13    FY1973            csv
# 14    FY1974            csv
# 15    FY1975            csv
# 16    FY1976            csv
# 17    FY1977            csv
# 18    FY1978            csv
# 19    FY1979            csv
# 20    FY1980            csv
# 21    FY1981            csv
# 22    FY1982            csv
# 23    FY1983            csv
# 24    FY1984            csv
# 25    FY1985            csv
# 26    FY1986            csv
# 27    FY1987            csv
# 28    FY1988            csv
# 29    FY1989            csv
# 30    FY1990            csv
# 31    FY1991            csv
# ...

# %%
df_veterans.to_json('../Data/Mine/Veterans/Reports/Documentation_individual_files_veterans_data.json', orient = 'records')

# %%
filename = '../Data/Mine/Veterans/Reports/Documentation_individual_files_veterans_data.json'
with open(filename, 'r') as f:
        datastore = json.load(f)
datastore
# Out:
# [{'Alternative_Notes': None,
#   'Alternative_URL': 'https://www.census.gov/library/publications/time-series/statistical_abstracts.html',
#   'Alternatively_obtained_from': 'Statistical Abstract of the United States',
#   'File_extension': 'csv',
#   'File_name': 'FY1960',
#   'Notes': None,
#   'Obtained_from': 'Annual report of the Secretary of Veterans Affairs',
#   'Original_file': 'FY1960_page171',
#   'Original_file_type': 'pdf',
#   'Page_in_original_file': '171',
#   'URL': 'https://www.va.gov/vetdata/Report.asp'},
#  {'Alternative_Notes': None,
#   'Alternative_URL': 'https://www.census.gov/library/publications/time-series/statistical_abstracts.html',
#   'Alternatively_obtained_from': 'Statistical Abstract of the United States',
#   'File_extension': 'csv',
#   'File_name': 'FY1961',
#   'Notes': None,
#   'Obtained_from': 'Annual report of the Secretary of Veterans Affairs',
#   'Original_file': 'FY1961_page189',
#   'Original_file_type': 'pdf',
# ...

# %%
# Out:
# 58

# %%
testing_df = pd.read_json(path_or_buf='../Data/Mine/Veterans/Reports/Readme_veterans_data.json', orient='records')
testing_df
# Out:
#                                     Alternative_Notes  \
# 0                                                None
# 1                                                None
# 2                                                None
# 3                                                None
# 4                                                None
# 5                                                None
# 6                                                None
# 7                                                None
# 8                                                None
# 9                                                None
# 10                                               None
# 11                                               None
# 12                                               None
# 13                                               None
# 14                                               None
# 15                                               None
# ...
